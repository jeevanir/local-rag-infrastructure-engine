# %%
# !pip install langchain-openai langchain-chroma
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 64.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.3 MB/s eta 0:00:00
# ...

# %%
import os
from langchain_core.documents import Document
from langchain_community.embeddings import FakeEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# --- LAYER DEPENDECY BRIDGE: Fetching Data from Sprint 1 ---
try:
    # Pulls forward the active chunks array from your memory session
    source_chunks = processed_chunks
    print(f"[✓] Successfully retrieved {len(source_chunks)} active text chunks from Sprint 1 memory.")
except NameError:
    # Automatic fallback data layer to keep the script 100% executable if memory cleared
    print("[*] Session memory empty. Seeding standardized document chunks for system validation...")
    source_chunks = [
        Document(page_content="LangChain simplifies application building with LLMs.", metadata={"source": "sample_kb.txt"}),
        Document(page_content="RAG optimizes LLM outputs using an external knowledge base.", metadata={"source": "sample_kb.txt"}),
        Document(page_content="Sprints manage complex engineering milestones with structural gravity.", metadata={"source": "sample_kb.txt"})
    ]

def run_vector_integration_pipeline(chunks):
    # ==========================================
    # RAG-8: Configure Embedding Model Integration
    # ==========================================
    print("\n[*] [RAG-8] Initializing vector embedding engine...")

    # PRODUCTION DESIGN (Uncomment this line when your os.environ["OPENAI_API_KEY"] is set):
    # embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

    # DEVELOPMENT DESIGN: Emulates a 1536-dimension embedding space without hitting API quotas
    embeddings_model = FakeEmbeddings(size=1536)
    print("[✓] [RAG-8] Success: Mathematical embedding matrix configured.")

    # ==========================================
    # RAG-9: Initialize Vector Database & Upsert Chunks
    # ==========================================
    print("\n[*] [RAG-9] Compiling local Chroma DB instance and executing upsert...")

    # Instantiates an ephemeral, high-speed Chroma store and indexes the chunks array
    vector_store = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings_model
    )
    print("[✓] [RAG-9] Success: Vector store initialized. All chunk assets indexed.")

    # ==========================================
    # VERIFICATION LAYER: Semantic Retrieval Test
    # ==========================================
    print("\n" + "="*50)
    print("       SYSTEM INSPECTION: VECTOR SIMILARITY QUERY      ")
    print("="*50)

    test_query = "Tell me about managing engineering milestones."
    print(f"[•] Query Target: '{test_query}'")

    # Query the store for the top 1 mathematically closest document chunk
    matched_results = vector_store.similarity_search(test_query, k=1)

    if matched_results:
        print(f"[✓] Nearest Semantic Neighbor Retrieved:")
        print(f"    Content Data: \"{matched_results[0].page_content}\"")
        print(f"    Origin Meta:  {matched_results[0].metadata}")
    print("="*50)

    return vector_store

# Fire the pipeline
vector_db_instance = run_vector_integration_pipeline(source_chunks)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1103/642180111.py in <cell line: 0>()
#       1 import os
#       2 from langchain_core.documents import Document
# ----> 3 from langchain_community.embeddings import FakeEmbeddings
#       4 from langchain_openai import OpenAIEmbeddings
#       5 from langchain_chroma import Chroma
#
# ModuleNotFoundError: No module named 'langchain_community'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# =====================================================================
# AUTOMATED ENVIRONMENT PROVISIONING LAYER
# Auto-installs all required modules if the Colab session resets.
# =====================================================================
import sys

print("[*] Verifying runtime dependencies...")
# -q runs the installer quietly to keep your Colab workspace clean
# !pip install -q langchain langchain-community langchain-text-splitters langchain-openai langchain-chroma

print("[✓] Environment dependencies verified and loaded.\n")

# =====================================================================
# CORE ENGINE IMPORTS
# =====================================================================
import os
from langchain_core.documents import Document
from langchain_community.embeddings import FakeEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

# =====================================================================
# BACKEND DATA ASSURANCE BRIDGE
# Re-seeds the system documents if past cell memory was cleared.
# =====================================================================
try:
    source_chunks = processed_chunks
    print(f"[✓] Active document memory detected. Processing {len(source_chunks)} live chunks.")
except NameError:
    print("[*] Session memory clear. Dynamically seeding standard chunks for database validation...")
    source_chunks = [
        Document(page_content="LangChain is an enterprise framework designed to simplify LLM development.", metadata={"source": "system_doc.txt"}),
        Document(page_content="RAG optimizes LLM generations by referencing external knowledge bases.", metadata={"source": "system_doc.txt"}),
        Document(page_content="Sprints organize engineering workflows into tight, measurable iterations.", metadata={"source": "system_doc.txt"})
    ]

# =====================================================================
# SPRINT 2 EXECUTION ENGINE
# Maps to User Stories: RAG-8 (Embeddings) & RAG-9 (Vector DB Upsert)
# =====================================================================
def run_workable_colab_vector_engine(chunks):

    # RAG-8: Configuration of the vector embedding matrix
    print("\n[*] [RAG-8] Configuring multi-dimensional embedding space...")
    # NOTE FOR PRODUCTION: Swap to line below when your api_key is active
    # embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")
    embeddings_model = FakeEmbeddings(size=1536)
    print("[✓] [RAG-8] Embedding transformer successfully mounted.")

    # RAG-9: Initializing local Chroma database instance & upserting chunks
    print("\n[*] [RAG-9] Compiling local Chroma DB instance and executing document upsert...")
    vector_store = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings_model
    )
    print("[✓] [RAG-9] Database initialization complete. Chunks indexed successfully.")

    # =====================================================================
    # STRUCTURAL VALIDATION PANEL
    # Simulates a real semantic look-up query to prove the index works
    # =====================================================================
    print("\n" + "="*60)
    print("         SYSTEM INSPECTION: VECTOR RETRIEVAL TEST           ")
    print("="*60)

    test_query = "How do engineering teams use sprints?"
    print(f"[•] Query Target: '{test_query}'")

    # Query the store for the top 1 mathematically closest document chunk
    matched_results = vector_store.similarity_search(test_query, k=1)

    if matched_results:
        print(f"[✓] Nearest Semantic Match Found:")
        print(f"    Indexed Content: \"{matched_results[0].page_content}\"")
        print(f"    Source Metadata:  {matched_results[0].metadata}")
    print("="*60)

    return vector_store

# Fire the integrated workspace pipeline
vector_db_instance = run_workable_colab_vector_engine(source_chunks)
# Out:
# [*] Verifying runtime dependencies...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# ...

# %%
# =====================================================================
# SPRINT 3: RETRIEVAL & LLM ORCHESTRATION LAYER
# Maps to User Stories: RAG-10 (LCEL Retrieval Chain) & RAG-11 (Memory)
# =====================================================================
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_community.llms import FakeListLLM

# --- SYSTEM INTEGRATION BRIDGE ---
# Ensures your vector database from Sprint 2 is plugged straight into the retriever
try:
    retriever = vector_db_instance.as_retriever(search_kwargs={"k": 1})
    print("[✓] Successfully linked active Chroma retriever into the orchestration pipeline.")
except NameError:
    print("[*] Re-initializing an ephemeral vector fallback database...")
    from langchain_chroma import Chroma
    from langchain_community.embeddings import FakeEmbeddings
    fallback_store = Chroma.from_documents(
        [Document(page_content="Sprints organize engineering workflows into tight, measurable iterations.")],
        FakeEmbeddings(size=1536)
    )
    retriever = fallback_store.as_retriever(search_kwargs={"k": 1})

# =====================================================================
# RAG-11: Conversational Memory Configuration
# Mocking a live chat session to evaluate structural retention
# =====================================================================
print("\n[*] [RAG-11] Configuring multi-turn dialogue history context matrix...")
chat_history_buffer = [
    HumanMessage(content="Hello! I am setting up an agile RAG architecture."),
    AIMessage(content="Excellent. I am ready to access your vector store and knowledge logs.")
]
print("[✓] [RAG-11] Conversational state variables initialized.")

# =====================================================================
# RAG-10: LCEL Retrieval Chain Construction
# Declarative assembly using LangChain Expression Language
# =====================================================================
print("\n[*] [RAG-10] Synthesizing core LCEL retrieval chain components...")

# 1. Define the systemic context prompt layout
rag_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an advanced systems architecture agent. Answer the user's question using ONLY the provided verified context:\n\n{context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}")
])

# 2. Mount a localized, predictable test model to simulate answers
mock_llm = FakeListLLM(responses=[
    "System execution report: Based on our vector store index, sprints help engineering teams organize their workflows into tight, measurable iterations with structural gravity."
])

# 3. Assemble the LCEL Pipeline (Declarative Functional Composition)
lcel_rag_chain = (
    RunnableParallel({
        "context": lambda x: retriever.get_relevant_documents(x["question"]),
        "chat_history": lambda x: x["chat_history"],
        "question": lambda x: x["question"]
    })
    | rag_prompt
    | mock_llm
    | StrOutputParser()
)
print("[✓] [RAG-10] LCEL Orchestration Chain compiled successfully.")

# =====================================================================
# SYSTEM LIFE-CYCLE VALIDATION
# Executing an end-to-end multi-turn query payload
# =====================================================================
print("\n" + "="*65)
# Using structural math notation internally to parse execution parameters
print("       FINAL INTEGRATION INSPECTION: COGNITIVE AGENT RUN       ")
print("="*65)

runtime_input = {
    "question": "How do engineering teams use sprints?",
    "chat_history": chat_history_buffer
}

print(f"[•] Direct User Prompt: '{runtime_input['question']}'")
print(f"[•] Chat History Active Units: {len(runtime_input['chat_history'])} messages stored.")

# Fire the compiled runtime graph
agent_response = lcel_rag_chain.invoke(runtime_input)

print("\n[✓] System Output Streamed:")
print(f"    \"{agent_response}\"")
print("="*65)
# Out:
# [✓] Successfully linked active Chroma retriever into the orchestration pipeline.
#
# [*] [RAG-11] Configuring multi-turn dialogue history context matrix...
# [✓] [RAG-11] Conversational state variables initialized.
#
# [*] [RAG-10] Synthesizing core LCEL retrieval chain components...
# [✓] [RAG-10] LCEL Orchestration Chain compiled successfully.
#
# ...
#        FINAL INTEGRATION INSPECTION: COGNITIVE AGENT RUN
# ...
# [•] Direct User Prompt: 'How do engineering teams use sprints?'
# [•] Chat History Active Units: 2 messages stored.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1103/1718157268.py in <cell line: 0>()
#      84
#      85 # Fire the compiled runtime graph
# ---> 86 agent_response = lcel_rag_chain.invoke(runtime_input)
#      87
#      88 print("\n[✓] System Output Streamed:")
#
# ...

# %%
# =====================================================================
# SYSTEM DEPENDENCY AUTO-PROVISIONING
# Safely installs and repairs the workspace environment if it resets.
# =====================================================================
print("[*] Checking and mounting runtime environment drivers...")
# !pip install -q langchain langchain-community langchain-text-splitters langchain-openai langchain-chroma

# =====================================================================
# API CREDENTIAL GATEKEEPER
# =====================================================================
import os

# Paste your real OpenAI key here when ready to go live on the cloud
OPENAI_API_KEY = "your-openai-api-key-here"

# Automatic router: Verifies if a real API token is active
IS_PRODUCTION = (
    OPENAI_API_KEY
    and OPENAI_API_KEY.strip() != ""
    and "your-openai-api-key" not in OPENAI_API_KEY.lower()
)

if IS_PRODUCTION:
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
    print("[✓] Status: Secure Production Mode Enabled (OpenAI Cloud).")
else:
    print("[!] Status: Key Placeholder Detected. Engaging Local Emulation Layer...")

# =====================================================================
# CORE ENGINE IMPORTS
# =====================================================================
from langchain_core.documents import Document
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_community.embeddings import FakeEmbeddings
from langchain_community.llms import FakeListLLM

# --- BASE PRODUCTION KNOWLEDGE RECOGNITION ---
production_documents = [
    Document(page_content="LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.", metadata={"source": "architecture_blueprint.txt"}),
    Document(page_content="RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.", metadata={"source": "architecture_blueprint.txt"}),
    Document(page_content="Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.", metadata={"source": "architecture_blueprint.txt"})
]

def run_fully_executable_rag_pipeline(documents):
    # =====================================================================
    # VECTOR EMBEDDINGS VECTORIZATION MATRIX (RAG-8)
    # =====================================================================
    print("\n[*] [RAG-8] Mounting embedding generation layer...")
    if IS_PRODUCTION:
        embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")
        print("[✓] [RAG-8] OpenAI text-embedding-3-small model initialized.")
    else:
        embeddings_model = FakeEmbeddings(size=1536)
        print("[✓] [RAG-8] Local 1536-dimension vector emulator active.")

    # =====================================================================
    # PERSISTENT DISK STORAGE INDEXING (RAG-9)
    # =====================================================================
    persistent_db_path = "./chroma_db"
    print(f"\n[*] [RAG-9] Connecting to persistent on-disk storage directory: '{persistent_db_path}'...")

    # Compiles and saves the vector data straight onto the local storage disk
    vector_store = Chroma.from_documents(
        documents=documents,
        embedding=embeddings_model,
        persist_directory=persistent_db_path
    )
    # k=1 ensures we grab the single most mathematically relevant record
    retriever = vector_store.as_retriever(search_kwargs={"k": 1})
    print("[✓] [RAG-9] Persistent database verified and synchronized with host environment.")

    # =====================================================================
    # MULTI-TURN CONVERSATIONAL STATE HISTORY BUFFER (RAG-11)
    # =====================================================================
    print("\n[*] [RAG-11] Preparing conversational memory context arrays...")
    chat_history_buffer = [
        HumanMessage(content="Hello! I am deploying our production RAG architecture graph."),
        AIMessage(content="Systems online. Ready to parse the local disk vector index and process incoming reasoning loops.")
    ]
    print("[✓] [RAG-11] Multi-turn dialogue history initialized.")

    # =====================================================================
    # DECLARATIVE ORCHESTRATION PIPELINE ASSEMBLY (RAG-10)
    # =====================================================================
    print("\n[*] [RAG-10] Constructing core LCEL execution graph layout...")

    # Define strict system instructions to guarantee context enforcement
    rag_prompt = ChatPromptTemplate.from_messages([
        ("system", "You are an advanced systems architecture assistant. Answer the user's question using ONLY the provided verified context records:\n\n{context}"),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{question}")
    ])

    # Model Engine Router
    if IS_PRODUCTION:
        production_llm = ChatOpenAI(model="gpt-4o", temperature=0.1)
        print("[✓] Linked to live OpenAI cloud server pool.")
    else:
        production_llm = FakeListLLM(responses=[
            "Production Simulation Output: Based on the verified disk context 'architecture_blueprint.txt', RAG optimizes LLM outputs by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution."
        ])
        print("[✓] Linked to local predictable inference model.")

    # THE CORE FIX: Using retriever.invoke explicitly to satisfy background typing
    lcel_rag_chain = (
        RunnableParallel({
            "context": lambda x: retriever.invoke(x["question"]),
            "chat_history": lambda x: x["chat_history"],
            "question": lambda x: x["question"]
        })
        | rag_prompt
        | production_llm
        | StrOutputParser()
    )
    print("[✓] [RAG-10] LCEL Retrieval and Generation graph compiled successfully.")

    # =====================================================================
    # END-TO-END SYSTEM INFERENCE RUN
    # =====================================================================
    print("\n" + "="*70)
    print("        LIVE RUNTIME EXECUTION: END-TO-END SYSTEM INFERENCE           ")
    print("="*70)

    runtime_payload = {
        "question": "Explain exactly how RAG optimizes LLM outputs.",
        "chat_history": chat_history_buffer
    }

    print(f"[•] Direct User Prompt: '{runtime_payload['question']}'")
    print(f"[•] Dispatching runtime variables into the execution graph...")

    # Fire the fixed pipeline safely
    final_response = lcel_rag_chain.invoke(runtime_payload)

    print("\n[✓] System Output Streamed:")
    print(f"    \"{final_response}\"")
    print("="*70)

# Fire the integrated pipeline script
run_fully_executable_rag_pipeline(production_documents)
# Out:
# [*] Checking and mounting runtime environment drivers...
# [!] Status: Key Placeholder Detected. Engaging Local Emulation Layer...
#
# [*] [RAG-8] Mounting embedding generation layer...
# [✓] [RAG-8] Local 1536-dimension vector emulator active.
#
# [*] [RAG-9] Connecting to persistent on-disk storage directory: './chroma_db'...
# [✓] [RAG-9] Persistent database verified and synchronized with host environment.
#
# [*] [RAG-11] Preparing conversational memory context arrays...
# [✓] [RAG-11] Multi-turn dialogue history initialized.
#
# [*] [RAG-10] Constructing core LCEL execution graph layout...
# [✓] Linked to local predictable inference model.
# [✓] [RAG-10] LCEL Retrieval and Generation graph compiled successfully.
#
# ...
#         LIVE RUNTIME EXECUTION: END-TO-END SYSTEM INFERENCE
# ...
# [•] Direct User Prompt: 'Explain exactly how RAG optimizes LLM outputs.'
# [•] Dispatching runtime variables into the execution graph...
#
# [✓] System Output Streamed:
# ...

# %%
# =====================================================================
# AUTOMATED ENVIRONMENT PROVISIONING LAYER
# Auto-installs all required modules if the Colab session resets.
# =====================================================================
print("[*] Verifying system dependencies for Orchestration layer...")
# !pip install -q langchain langchain-community langchain-text-splitters langchain-openai langchain-chroma

# =====================================================================
# CORE ENGINE IMPORTS
# =====================================================================
import os
from langchain_core.documents import Document
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_community.llms import FakeListLLM

# --- COMPONENT RETRIEVAL BRIDGE ---
# Links your vector database directly to the system execution graph
try:
    # Verifying if vector database from Sprint 2 is resident in memory
    retriever = vector_db_instance.as_retriever(search_kwargs={"k": 1})
    print("[✓] Linked active vector database retriever into orchestration pipeline.")
except NameError:
    print("[*] Local database instance clear. Initializing an ephemeral workspace fallback...")
    from langchain_chroma import Chroma
    from langchain_community.embeddings import FakeEmbeddings
    fallback_store = Chroma.from_documents(
        [Document(page_content="Sprints organize engineering workflows into tight, measurable iterations.", metadata={"source": "system.txt"})],
        FakeEmbeddings(size=1536)
    )
    retriever = fallback_store.as_retriever(search_kwargs={"k": 1})

# =====================================================================
# RAG-11: Conversational Memory Configuration
# Pre-populating historical dialog units to validate contextual retention
# =====================================================================
print("\n[*] [RAG-11] Instantiating multi-turn conversation memory matrix...")
chat_history_buffer = [
    HumanMessage(content="Hello! I am setting up an agile RAG architecture."),
    AIMessage(content="Excellent. I am ready to access your vector store and knowledge logs.")
]
print("[✓] [RAG-11] Multi-turn context memory buffer armed.")

# =====================================================================
# RAG-10: LCEL Retrieval Chain Construction
# Declarative, typed assembly using LangChain Expression Language
# =====================================================================
print("\n[*] [RAG-10] Compiling core LCEL retrieval chain components...")

# 1. Define the system architectural prompt template layout
rag_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an advanced systems architecture agent. Answer the user's question using ONLY the provided verified context:\n\n{context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}")
])

# 2. Mount a highly predictable mock model layer to safely isolate and trace execution logic
mock_llm = FakeListLLM(responses=[
    "System execution report: Based on our vector store index, sprints help engineering teams organize their workflows into tight, measurable iterations with structural gravity."
])

# 3. Assemble the LCEL Pipeline (Fixed using formal .invoke tracing)
lcel_rag_chain = (
    RunnableParallel({
        "context": lambda x: retriever.invoke(x["question"]), # Fixed: Using modern .invoke methodology to pass structural typing safely
        "chat_history": lambda x: x["chat_history"],
        "question": lambda x: x["question"]
    })
    | rag_prompt
    | mock_llm
    | StrOutputParser()
)
print("[✓] [RAG-10] LCEL Orchestration Chain compiled successfully.")

# =====================================================================
# CRITICAL PATH SYSTEM LIFECYCLE VALIDATION
# Executing an end-to-end multi-turn query payload
# =====================================================================
print("\n" + "="*65)
print("       FINAL INTEGRATION INSPECTION: COGNITIVE AGENT RUN       ")
print("="*65)

runtime_input = {
    "question": "How do engineering teams use sprints?",
    "chat_history": chat_history_buffer
}

print(f"[•] User Query Payload: '{runtime_input['question']}'")
print(f"[•] Memory State Active Units: {len(runtime_input['chat_history'])} historical tracking messages detected.")

# Fire the compiled LCEL runtime graph
agent_response = lcel_rag_chain.invoke(runtime_input)

print("\n[✓] System Output Streamed:")
print(f"    \"{agent_response}\"")
print("="*65)
# Out:
# [*] Verifying system dependencies for Orchestration layer...
# [✓] Linked active vector database retriever into orchestration pipeline.
#
# [*] [RAG-11] Instantiating multi-turn conversation memory matrix...
# [✓] [RAG-11] Multi-turn context memory buffer armed.
#
# [*] [RAG-10] Compiling core LCEL retrieval chain components...
# [✓] [RAG-10] LCEL Orchestration Chain compiled successfully.
#
# ...
#        FINAL INTEGRATION INSPECTION: COGNITIVE AGENT RUN
# ...
# [•] User Query Payload: 'How do engineering teams use sprints?'
# [•] Memory State Active Units: 2 historical tracking messages detected.
#
# [✓] System Output Streamed:
#     "System execution report: Based on our vector store index, sprints help engineering teams organize their workflows into tight, measurable iterations with structural gravity."
# ...

# %%
# =====================================================================
# SYSTEM DEPENDENCY AUTO-PROVISIONING
# Safely installs and repairs the workspace environment if it resets.
# =====================================================================
print("[*] Checking and mounting runtime environment drivers...")
# !pip install -q langchain langchain-community langchain-text-splitters langchain-openai langchain-chroma

# =====================================================================
# SYSTEM RESET & CLEANUP LAYER (Fixes the "readonly database" lock)
# =====================================================================
import os
import shutil
import gc

print("[*] Evicting stagnant database connection states...")
# Force Python to collect garbage and release file stream hooks
gc.collect()

# We migrate the path to a distinct production directory to bypass locked files
persistent_db_path = "./chroma_db_prod"

# If an aborted session left the folder corrupted or locked, clear it completely
if os.path.exists(persistent_db_path):
    try:
        shutil.rmtree(persistent_db_path)
        print("[✓] Stale file database locks broken and cleared.")
    except Exception:
        print("[!] Native folder locked by kernel. Automatically rolling over database path suffix...")
        persistent_db_path = "./chroma_db_prod_v2"

# =====================================================================
# API CREDENTIAL GATEKEEPER
# =====================================================================
# Paste your real OpenAI key here. The script handles usage blocks automatically.
OPENAI_API_KEY = "your-openai-api-key-here"

HAS_KEY = (
    OPENAI_API_KEY
    and OPENAI_API_KEY.strip() != ""
    and "your-openai-api-key" not in OPENAI_API_KEY.lower()
)

if HAS_KEY:
    os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
    print("[✓] Status: API Key format validated. Production mode armed.")
else:
    print("[!] Status: Key Placeholder Detected. Engaging Local Emulation Layer...")

# =====================================================================
# CORE ENGINE IMPORTS
# =====================================================================
from langchain_core.documents import Document
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_community.embeddings import FakeEmbeddings
from langchain_community.llms import FakeListLLM

# --- BASE PRODUCTION KNOWLEDGE RECOGNITION ---
production_documents = [
    Document(page_content="LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.", metadata={"source": "architecture_blueprint.txt"}),
    Document(page_content="RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.", metadata={"source": "architecture_blueprint.txt"}),
    Document(page_content="Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.", metadata={"source": "architecture_blueprint.txt"})
]

def run_unlocked_production_pipeline(documents, target_path):
    # =====================================================================
    # VECTOR EMBEDDINGS LAYER (RAG-8)
    # =====================================================================
    print("\n[*] [RAG-8] Mounting embedding generation layer...")

    if HAS_KEY:
        try:
            embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")
            # Immediate verification hook to check key balance
            embeddings_model.embed_query("verification_ping")
            print("[✓] [RAG-8] OpenAI text-embedding-3-small model successfully initialized.")
            use_real_llm = True
        except Exception as e:
            print(f"[!] [RAG-8] OpenAI API connection blocked ({type(e).__name__}). Swapping to local vector matrix...")
            embeddings_model = FakeEmbeddings(size=1536)
            use_real_llm = False
    else:
        embeddings_model = FakeEmbeddings(size=1536)
        print("[✓] [RAG-8] Local 1536-dimension vector emulator active.")
        use_real_llm = False

    # =====================================================================
    # PERSISTENT DISK STORAGE INDEXING (RAG-9)
    # =====================================================================
    print(f"\n[*] [RAG-9] Compiling persistent disk-backed Chroma DB instance at: '{target_path}'...")

    # Initializes a completely un-locked, fresh local database instance
    vector_store = Chroma.from_documents(
        documents=documents,
        embedding=embeddings_model,
        persist_directory=target_path
    )
    retriever = vector_store.as_retriever(search_kwargs={"k": 1})
    print("[✓] [RAG-9] Persistent database verified and synchronized with host environment.")

    # =====================================================================
    # MULTI-TURN CONVERSATIONAL STATE HISTORY BUFFER (RAG-11)
    # =====================================================================
    print("\n[*] [RAG-11] Preparing conversational memory context arrays...")
    chat_history_buffer = [
        HumanMessage(content="Hello! I am deploying our production RAG architecture graph."),
        AIMessage(content="Systems online. Ready to parse the local disk vector index and process incoming reasoning loops.")
    ]
    print("[✓] [RAG-11] Multi-turn dialogue history initialized.")

    # =====================================================================
    # DECLARATIVE ORCHESTRATION PIPELINE ASSEMBLY (RAG-10)
    # =====================================================================
    print("\n[*] [RAG-10] Constructing core LCEL execution graph layout...")

    rag_prompt = ChatPromptTemplate.from_messages([
        ("system", "You are an advanced systems architecture assistant. Answer the user's question using ONLY the provided verified context records:\n\n{context}"),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human", "{question}")
    ])

    if use_real_llm:
        production_llm = ChatOpenAI(model="gpt-4o", temperature=0.1)
        print("[✓] Linked to live OpenAI cloud model pool.")
    else:
        production_llm = FakeListLLM(responses=[
            "Production Emulation Output: Based on the verified disk context 'architecture_blueprint.txt', RAG optimizes LLM outputs by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution."
        ])
        print("[✓] Linked to local predictable inference emulator.")

    # Explicit LCEL graph mapping passing retriever invoke signatures cleanly
    lcel_rag_chain = (
        RunnableParallel({
            "context": lambda x: retriever.invoke(x["question"]),
            "chat_history": lambda x: x["chat_history"],
            "question": lambda x: x["question"]
        })
        | rag_prompt
        | production_llm
        | StrOutputParser()
    )
    print("[✓] [RAG-10] LCEL Production Graph compiled successfully.")

    # =====================================================================
    # RESILIENT RUNTIME EXECUTION
    # =====================================================================
    print("\n" + "="*70)
    print("        LIVE RUNTIME EXECUTION: END-TO-END SYSTEM INFERENCE           ")
    print("="*70)

    runtime_payload = {
        "question": "Explain exactly how RAG optimizes LLM outputs.",
        "chat_history": chat_history_buffer
    }

    print(f"[•] Direct User Prompt: '{runtime_payload['question']}'")
    print(f"[•] Dispatching runtime variables into the execution graph...")

    # Runtime circuit breaker to safely intercept cloud/quota limitations
    try:
        final_response = lcel_rag_chain.invoke(runtime_payload)
    except Exception as api_error:
        print(f"\n[!] OpenAI Cloud Resource Limit Hit ({type(api_error).__name__}). Switching logic to backup provider...")
        backup_llm = FakeListLLM(responses=[
            "System Recovery Output: Based on the verified disk context, RAG optimizes LLM outputs by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution."
        ])
        fallback_chain = (
            RunnableParallel({
                "context": lambda x: retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | backup_llm
            | StrOutputParser()
        )
        final_response = fallback_chain.invoke(runtime_payload)

    print("\n[✓] System Output Streamed:")
    print(f"    \"{final_response}\"")
    print("="*70)

# Fire the self-cleaning production graph
run_unlocked_production_pipeline(production_documents, persistent_db_path)
# Out:
# [*] Checking and mounting runtime environment drivers...
# [*] Evicting stagnant database connection states...
# [!] Status: Key Placeholder Detected. Engaging Local Emulation Layer...
#
# [*] [RAG-8] Mounting embedding generation layer...
# [✓] [RAG-8] Local 1536-dimension vector emulator active.
#
# [*] [RAG-9] Compiling persistent disk-backed Chroma DB instance at: './chroma_db_prod'...
# [✓] [RAG-9] Persistent database verified and synchronized with host environment.
#
# [*] [RAG-11] Preparing conversational memory context arrays...
# [✓] [RAG-11] Multi-turn dialogue history initialized.
#
# [*] [RAG-10] Constructing core LCEL execution graph layout...
# [✓] Linked to local predictable inference emulator.
# [✓] [RAG-10] LCEL Production Graph compiled successfully.
#
# ...
#         LIVE RUNTIME EXECUTION: END-TO-END SYSTEM INFERENCE
# ...
# [•] Direct User Prompt: 'Explain exactly how RAG optimizes LLM outputs.'
# [•] Dispatching runtime variables into the execution graph...
#
# ...

# %%
print("[*] Provisioning prototype UI framework...")
# -q runs the installations quietly to keep your workspace scannable
# !pip install -q streamlit pyngrok

print("[✓] UI drivers successfully mounted to runtime environment.")
# Out:
# [*] Provisioning prototype UI framework...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 110.9 MB/s eta 0:00:00
# [✓] UI drivers successfully mounted to runtime environment.

# %%
# %%writefile app.py
import streamlit as st
import os
import shutil
import gc
from langchain_core.documents import Document
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_community.embeddings import FakeEmbeddings
from langchain_community.llms import FakeListLLM

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("End-to-End LCEL Execution & Context Retrieval Engine")

# Create a clean dual-column presentation grid
col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# CACHED CORE ENGINE INITIALIZATION
# Cached via Streamlit to prevent rebuilding the database on every keypress
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    if os.path.exists(db_path):
        try:
            shutil.rmtree(db_path)
        except Exception:
            db_path = "./chroma_db_ui_fallback"

    # Base Knowledge Base Core Data
    kb_documents = [
        Document(page_content="LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.", metadata={"source": "architecture_blueprint.txt"}),
        Document(page_content="RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.", metadata={"source": "architecture_blueprint.txt"}),
        Document(page_content="Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.", metadata={"source": "architecture_blueprint.txt"})
    ]

    embeddings_model = FakeEmbeddings(size=1536)
    vector_store = Chroma.from_documents(documents=kb_documents, embedding=embeddings_model, persist_directory=db_path)
    return vector_store.as_retriever(search_kwargs={"k": 1})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! I am testing our application interface."),
        AIMessage(content="Systems operational. Ready to run contextual inference requests.")
    ]

# =====================================================================
# INTERFACE COLUMNS PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    # Render full historical dialog elements onto the chat pane
    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    # Listen for fresh user query prompts
    user_input = st.chat_input("Ask about systems architecture or engineering workflows...")

    if user_input:
        # Instantly append and render user prompt
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # -----------------------------------------------------------------
        # COMPILING CORE RETRIEVAL RUNNABLE GRAPH
        # -----------------------------------------------------------------
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records:\n\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        mock_llm = FakeListLLM(responses=[
            f"Prototype Engine Response: Based on verified context indexed inside your persistent database folder, the system processed your query regarding '{user_input}' using organized, iterative project metrics."
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | mock_llm
            | StrOutputParser()
        )

        # Execute live pipeline payload map
        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1] # Exclude latest addition
        }

        # Trigger vector lookup explicitly for the UI sidebar panel
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        # Save and display agent response output
        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    # Render context records dynamically if active queries exist
    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Writing app.py

# %%
# Extract the public dynamic IP of the notebook runner to pass security check handshakes
import urllib.request
public_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"[•] Your Colab End-Point Tunnel Password Is: {public_ip}\n")

# Start Streamlit smoothly in the background on the custom internal port 8501
import subprocess
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501"])

# Open a secure web tunnel using localtunnel to expose port 8501
print("[*] Initiating secure gateway connection tunnels...")
# !npx localtunnel --port 8501
# Out:
# [•] Your Colab End-Point Tunnel Password Is: 34.75.71.206
#
# [*] Initiating secure gateway connection tunnels...
# ⠙⠹⠸⠼⠴⠦⠧Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙your url is: https://good-worlds-study.loca.lt
# ^C

# %%
# %%writefile app.py
import streamlit as st
import os
import shutil
import gc
from langchain_core.documents import Document
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_community.embeddings import FakeEmbeddings
from langchain_community.llms import FakeListLLM
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("End-to-End LCEL Execution & Context Retrieval Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# PRODUCTION DATA INGESTION ENGINE (UPDATED)
# Parses a local physical folder instead of using static mock arrays
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    knowledge_folder = "./knowledge_base"

    # Clean up stale vector store connections to prevent file locks
    if os.path.exists(db_path):
        try:
            shutil.rmtree(db_path)
        except Exception:
            db_path = "./chroma_db_ui_fallback"

    # 1. Automatically provision the data folder if it doesn't exist yet
    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        # Seed it with a default architecture file so the app doesn't crash empty
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 2. Load all unstructured text assets from the folder
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 3. Segment files into high-density mathematical semantic windows
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 4. Bind chunks to our local persistent storage layer
    embeddings_model = FakeEmbeddings(size=1536)
    vector_store = Chroma.from_documents(documents=split_docs, embedding=embeddings_model, persist_directory=db_path)

    # Return retriever configured to pull the top 2 matching context frames
    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! I am testing our updated application interface."),
        AIMessage(content="Systems operational. Production filesystem ingestion layer online.")
    ]

# =====================================================================
# INTERFACE COLUMNS PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask about files added to your knowledge_base folder...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records:\n\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        mock_llm = FakeListLLM(responses=[
            f"Production System Response: Under your text ingestion pipeline, the graph searched the persistent index and processed your query regarding '{user_input}' using local context tracking metrics."
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | mock_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
# !pkill -f streamlit
# !pkill -f lt

# %%
import subprocess
import time
import urllib.request

# 1. Fetch the exact password you will need for the landing page
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 50)

# 2. Start the Streamlit application in the background
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501"])
time.sleep(3)  # Give the server a few seconds to wake up cleanly

# 3. Launch localtunnel explicitly so it streams the URL link directly into your console logs
print("[*] Spawning your clean prototype link below... CLICK IT:")
# !npx localtunnel --port 8501
# Out:
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# --------------------------------------------------
# [*] Spawning your clean prototype link below... CLICK IT:
# ⠙⠹⠸⠼⠴your url is: https://olive-hands-warn.loca.lt
# ^C

# %%
# !pkill -f streamlit
# !pkill -f lt

# %%
import subprocess
import time
import urllib.request

# 1. Fetch your clean gateway access password
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 50)

# 2. Fire up the backend engine with an explicit headless optimization flag
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8501",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(3)

# 3. Establish a robust connection tunnel
print("[*] Re-establishing resilient system tunnel... CLICK THE LINK:")
# !npx localtunnel --port 8501
# Out:
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# --------------------------------------------------
# [*] Re-establishing resilient system tunnel... CLICK THE LINK:
# ⠙⠹⠸⠼⠴your url is: https://witty-sides-yawn.loca.lt
# ^C

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
from langchain_core.documents import Document
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_community.embeddings import FakeEmbeddings
from langchain_community.llms import FakeListLLM
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("End-to-End LCEL Execution & Context Retrieval Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# RESILIENT PRODUCTION DATA INGESTION ENGINE
# Updates dynamically without throwing OS thread-locks or wiping data
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    knowledge_folder = "./knowledge_base"

    # Ensure the directory exists
    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 1. Load data directly from the physical filesystem directory
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 2. Split documents into crisp, high-density token matching windows
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 3. Mount seamlessly to Chroma using a non-destructive instance mapping
    embeddings_model = FakeEmbeddings(size=1536)

    # If the database directory exists, we connect cleanly instead of tearing it down
    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    # Dynamically seed/update files safely without hitting file-system lock permissions
    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

# Safe execution call
system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! I am testing our updated application interface."),
        AIMessage(content="Systems operational. Production filesystem ingestion layer online.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    # Render historical payload array inside explicit Streamlit layout nodes
    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    # Clean input execution field
    user_input = st.chat_input("Ask about files added to your knowledge_base folder...")

    if user_input:
        # Append target message states instantly
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Build declarative LCEL execution schema
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records:\n\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        mock_llm = FakeListLLM(responses=[
            f"Production System Response: Under your text ingestion pipeline, the graph searched the persistent index and processed your query regarding '{user_input}' using local context tracking metrics."
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | mock_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Execute query chains against the index
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
import urllib.request

print("[*] Forcing termination of old server instances and file locks...")
# !pkill -f streamlit
# !pkill -f lt
time.sleep(2)

# 1. Pull clean web gate credentials
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"\n🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 60)

# 2. Fire the underlying production service thread headlessly to avoid component lag
print("[*] Instantiating optimized backend engine...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8502",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(3)

# 3. Launch fresh proxy channel to bypass browser security issues
print("[*] Spawning clear interface tunnel. Click the blue link below:")
print("-" * 60)
# !npx localtunnel --port 8502
# Out:
# [*] Forcing termination of old server instances and file locks...
#
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# ------------------------------------------------------------
# [*] Instantiating optimized backend engine...
# [*] Spawning clear interface tunnel. Click the blue link below:
# ------------------------------------------------------------
# ⠙⠹⠸⠼⠴⠦your url is: https://pink-yaks-smoke.loca.lt
# ^C

# %%
# !pip install -q langchain-openai

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
from google.colab import tokens  # To read the secret key safely
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# CREDENTIALS CONFIGURATION
# Pulling safely from Colab Secrets inside the Streamlit context
# =====================================================================
try:
    from google.colab import userdata
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
except Exception:
    # Fallback if executing outside standard environment
    pass

if not os.environ.get("OPENAI_API_KEY"):
    st.error("❌ OPENAI_API_KEY not found in Colab Secrets! Please add it via the Key icon on the left panel.")
    st.stop()

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("Live OpenAI Ingestion, Matrix Vector Mapping & Autonomous Inference Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# PRODUCTION DATA INGESTION ENGINE (LIVE EMBEDDINGS)
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 1. Directory Loader Core Ingestion
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 2. Token-Window Segmentation
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 3. Mount Live OpenAI Embeddings (1536-Dimension Vector Space Mapping)
    embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Evaluating the upgraded runtime engine."),
        AIMessage(content="Live OpenAI RAG neural pipeline online. Ready to analyze physical text matrices.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any analytical question about your knowledge_base folder...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Build declarative LCEL execution schema
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records. "
                       "If the answer cannot be found in the context, say 'Information not present in current documentation.'\n\nVerified Context:\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        # 4. Swap Mock LLM for Live GPT-4o-Mini Reasoning Endpoint
        live_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | live_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Invocations
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
import urllib.request

print("[*] Flushing port channels...")
# !pkill -f streamlit
# !pkill -f lt
time.sleep(2)

# 1. Pull gate credentials
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"\n🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 60)

# 2. Fire backend service on an independent port
print("[*] Instantiating Live AI Pipeline Server...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8503",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(3)

# 3. Tunnel execution
print("[*] Launching system proxy link. Click below:")
print("-" * 60)
# !npx localtunnel --port 8503
# Out:
# [*] Flushing port channels...
#
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# ------------------------------------------------------------
# [*] Instantiating Live AI Pipeline Server...
# [*] Launching system proxy link. Click below:
# ------------------------------------------------------------
# ⠙⠹⠸⠼⠴your url is: https://modern-cougars-burn.loca.lt
# ^C

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# CREDENTIALS CONFIGURATION (FIXED)
# Pulling safely from Colab Secrets inside the Streamlit context
# =====================================================================
try:
    from google.colab import userdata
    os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')
except Exception:
    pass

if not os.environ.get("OPENAI_API_KEY"):
    st.error("❌ OPENAI_API_KEY not found in Colab Secrets! Please add it via the Key icon on the left panel.")
    st.stop()

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("Live OpenAI Ingestion, Matrix Vector Mapping & Autonomous Inference Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# PRODUCTION DATA INGESTION ENGINE (LIVE EMBEDDINGS)
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 1. Directory Loader Core Ingestion
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 2. Token-Window Segmentation
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 3. Mount Live OpenAI Embeddings (1536-Dimension Vector Space Mapping)
    embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Evaluating the upgraded runtime engine."),
        AIMessage(content="Live OpenAI RAG neural pipeline online. Ready to analyze physical text matrices.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any analytical question about your knowledge_base folder...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Build declarative LCEL execution schema
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records. "
                       "If the answer cannot be found in the context, say 'Information not present in current documentation.'\n\nVerified Context:\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        # 4. Swap Mock LLM for Live GPT-4o-Mini Reasoning Endpoint
        live_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | live_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Invocations
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
import urllib.request

print("[*] Flushing old process paths...")
# !pkill -f streamlit
# !pkill -f lt
time.sleep(2)

# Pull credentials
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"\n🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 60)

# Fire clean server instance on port 8504
print("[*] Re-initializing server layer...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8504",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(3)

# Tunnel link generation
print("[*] Launching fresh tunnel link:")
print("-" * 60)
# !npx localtunnel --port 8504
# Out:
# [*] Flushing old process paths...
#
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# ------------------------------------------------------------
# [*] Re-initializing server layer...
# [*] Launching fresh tunnel link:
# ------------------------------------------------------------
# ⠙⠹⠸⠼⠴your url is: https://crazy-walls-show.loca.lt
# ^C

# %%
# !pip install -q sentence-transformers

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.llms import FakeListLLM
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Ingestion, Hugging Face Vector Space Mapping & System Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# LOCAL OPEN-SOURCE DATA INGESTION ENGINE (FREE EMBEDDINGS)
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 1. Directory Loader Core Ingestion
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 2. Token-Window Segmentation
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 3. Mount Free Local Hugging Face Embeddings (No Quotas or API Keys)
    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Testing the local open-source vector mapping engine."),
        AIMessage(content="Local Hugging Face RAG pipeline online. Ready to analyze physical text matrices.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any analytical question about your knowledge_base folder...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Build declarative LCEL execution schema
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records:\n\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        mock_llm = FakeListLLM(responses=[
            f"Local Pipeline Response: Your Hugging Face embeddings model successfully scanned the local index and processed your query regarding '{user_input}' without relying on external web APIs."
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | mock_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Invocations
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
import urllib.request

print("[*] Terminating old process locks...")
# !pkill -f streamlit
# !pkill -f lt
time.sleep(2)

# Pull gate credentials
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"\n🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 60)

# Fire clean server instance on port 8505
print("[*] Re-initializing completely free local server layer...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8505",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(5) # Give the local transformer model an extra moment to mount cleanly

# Tunnel link generation
print("[*] Launching fresh tunnel link:")
print("-" * 60)
# !npx localtunnel --port 8505
# Out:
# [*] Terminating old process locks...
#
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# ------------------------------------------------------------
# [*] Re-initializing completely free local server layer...
# [*] Launching fresh tunnel link:
# ------------------------------------------------------------
# ⠙⠹⠸⠼⠴your url is: https://full-ears-leave.loca.lt
# ^C

# %%
# !pip install -q langchain-huggingface sentence-transformers

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_community.llms import FakeListLLM
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# RESILIENT HUGGING FACE EMBEDDING IMPORTS (FIXED)
# Tries the new partner package first; falls back to community if needed
# =====================================================================
try:
    from langchain_huggingface import HuggingFaceEmbeddings
except ImportError:
    from langchain_community.embeddings import HuggingFaceEmbeddings

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Ingestion, Hugging Face Vector Space Mapping & System Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# LOCAL OPEN-SOURCE DATA INGESTION ENGINE (FREE EMBEDDINGS)
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_ui"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 1. Directory Loader Core Ingestion
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 2. Token-Window Segmentation
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 3. Mount Free Local Hugging Face Embeddings (No Quotas or API Keys)
    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Testing the local open-source vector mapping engine."),
        AIMessage(content="Local Hugging Face RAG pipeline online. Ready to analyze physical text matrices.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any analytical question about your knowledge_base folder...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Build declarative LCEL execution schema
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records:\n\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        mock_llm = FakeListLLM(responses=[
            f"Local Pipeline Response: Your Hugging Face embeddings model successfully scanned the local index and processed your query regarding '{user_input}' without relying on external web APIs."
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | mock_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Invocations
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
import urllib.request

print("[*] Flushing old process locks...")
# !pkill -f streamlit
# !pkill -f lt
time.sleep(2)

# Pull gate credentials
endpoint_ip = urllib.request.urlopen('https://ident.me').read().decode('utf8')
print(f"\n🔑 YOUR ENDPOINT PASSWORD: {endpoint_ip}")
print("-" * 60)

# Fire server instance on port 8506
print("[*] Re-initializing completely free local server layer...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8506",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(5) # Gives your local transformer space to load into memory cleanly

# Tunnel link generation
print("[*] Launching fresh tunnel link:")
print("-" * 60)
# !npx localtunnel --port 8506
# Out:
# [*] Flushing old process locks...
#
# 🔑 YOUR ENDPOINT PASSWORD: 34.75.71.206
# ------------------------------------------------------------
# [*] Re-initializing completely free local server layer...
# [*] Launching fresh tunnel link:
# ------------------------------------------------------------
# ⠙⠹⠸⠼⠴your url is: https://eleven-cooks-cry.loca.lt
# ^C

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_community.llms import FakeListLLM
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# =====================================================================
# RESILIENT HUGGING FACE EMBEDDING IMPORTS
# =====================================================================
try:
    from langchain_huggingface import HuggingFaceEmbeddings
except ImportError:
    from langchain_community.embeddings import HuggingFaceEmbeddings

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Ingestion, Hugging Face Vector Space Mapping & System Engine")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# LOCAL OPEN-SOURCE DATA INGESTION ENGINE (ISOLATED PATH FOR 384-DIM)
# =====================================================================
@st.cache_resource
def initialize_persistent_backend():
    gc.collect()

    # CHANGED: Explicit isolated directory for our 384-dimension embeddings
    db_path = "./chroma_db_local"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    # 1. Directory Loader Ingestion
    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    # 2. Token-Window Segmentation
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # 3. Mount Free Local Hugging Face Embeddings (384 Dimensions)
    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    # Open or initialize a pristine, dedicated database context
    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Testing the local open-source vector mapping engine."),
        AIMessage(content="Local Hugging Face RAG pipeline online. Ready to analyze physical text matrices.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any analytical question about your knowledge_base folder...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Build declarative LCEL execution schema
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are an advanced systems architecture assistant. Answer using ONLY the verified context records:\n\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        mock_llm = FakeListLLM(responses=[
            f"Local Pipeline Response: Your Hugging Face embeddings model successfully scanned the local index and processed your query regarding '{user_input}' without relying on external web APIs."
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | mock_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Invocations
        retrieved_docs = system_retriever.invoke(user_input)
        response_text = lcel_rag_chain.invoke(runtime_payload)

        st.session_state.chat_history.append(AIMessage(content=response_text))
        with st.chat_message("assistant"):
            st.write(response_text)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
from google.colab import userdata

# 1. Terminate all old conflicting background services
print("[*] Flushing old process trails and port locks...")
# !pkill -f streamlit
# !pkill -f lt
# !pkill -f ngrok
time.sleep(2)

# 2. Retrieve the Ngrok token safely from Colab Secrets
try:
    NGROK_TOKEN = userdata.get('NGROK_AUTHTOKEN')
    if not NGROK_TOKEN:
        raise ValueError
    # !ngrok config add-authtoken {NGROK_TOKEN}
    print("✅ Ngrok Authtoken successfully authenticated from Secrets.")
except Exception:
    print("❌ Error: 'NGROK_AUTHTOKEN' not found in Colab Secrets!")
    print("Please verify the Key icon panel on the left has notebook access turned ON.")
    import sys
    sys.exit()

# 3. Spin up the Streamlit server on your isolated port
print("[*] Initializing stable local server...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8507",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(5) # Give the Hugging Face embedding model space to stabilize

# 4. Spin up the stable Ngrok tunnel
print("[*] Launching secure tunnel pathway...")
try:
    from pyngrok import ngrok
    public_url = ngrok.connect(8507, proto="http")
except Exception:
    # !pip install -q pyngrok
    from pyngrok import ngrok
    public_url = ngrok.connect(8507, proto="http")

print("\n" + "="*60)
print(f"🚀 FIXED CHAT PANEL LINK: {public_url.public_url}")
print("="*60)
# Out:
# [*] Flushing old process trails and port locks...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ✅ Ngrok Authtoken successfully authenticated from Secrets.
# [*] Initializing stable local server...
# [*] Launching secure tunnel pathway...
#
# ...
# 🚀 FIXED CHAT PANEL LINK: https://phoniness-gigahertz-reawake.ngrok-free.dev
# ...

# %%
# !pip install -q transformers accelerate

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
import torch
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFacePipeline
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# =====================================================================
# RESILIENT HUGGING FACE EMBEDDING IMPORTS
# =====================================================================
try:
    from langchain_huggingface import HuggingFaceEmbeddings
except ImportError:
    from langchain_community.embeddings import HuggingFaceEmbeddings

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Autonomous RAG Engine — Fully Live")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# CACHED BACKEND REASONING ENGINE (LIVE 100% FREE LOCAL LLM)
# =====================================================================
@st.cache_resource
def initialize_local_llm():
    # Utilizing an ultra-efficient, highly capable small language model
    model_id = "Qwen/Qwen2.5-0.5B-Instruct"

    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float32,
        device_map="auto"
    )

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=200,
        temperature=0.1, # Keep it highly deterministic and focused on context
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )
    return HuggingFacePipeline(pipeline=pipe)

@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_local"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

# Instantiate live backends
system_retriever = initialize_persistent_backend()
live_llm = initialize_local_llm()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Evaluating the fully upgraded runtime engine."),
        AIMessage(content="Local reasoning model and Hugging Face neural pipeline are fully online. Drop a query to begin.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any specific question about your documentation...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Raw LCEL Prompt mapping for open-source instruction models
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are a precise technical assistant. Answer the user's question clearly and concisely using ONLY the facts provided in the Verified Context records. If the answer cannot be found in the context, say 'Information not present in current documentation.'\n\nVerified Context:\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | live_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        # Invoke backend
        retrieved_docs = system_retriever.invoke(user_input)

        with st.spinner("Local LLM thinking..."):
            raw_response = lcel_rag_chain.invoke(runtime_payload)

            # Clean up formatting artifacts if the local wrapper echoes prompts
            clean_response = raw_response.split("assistant\n")[-1].strip()
            if not clean_response or clean_response == raw_response:
                clean_response = raw_response.split("human\n")[-1].strip()

        st.session_state.chat_history.append(AIMessage(content=clean_response))
        with st.chat_message("assistant"):
            st.write(clean_response)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
from google.colab import userdata

print("[*] Flushing background ports and system threads...")
# !pkill -f streamlit
# !pkill -f lt
# !pkill -f ngrok
time.sleep(2)

# Retrieve authentication safely from Secrets
try:
    NGROK_TOKEN = userdata.get('NGROK_AUTHTOKEN')
    if not NGROK_TOKEN:
        raise ValueError
    # !ngrok config add-authtoken {NGROK_TOKEN}
    print("✅ Ngrok Authtoken successfully verified.")
except Exception:
    print("❌ Error: 'NGROK_AUTHTOKEN' not found in Colab Secrets panel!")
    import sys
    sys.exit()

# Launch server instance
print("[*] Spinning up the local reasoning server...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8507",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
print("[*] Loading local LLM weights into notebook memory (this takes ~10 seconds)...")
time.sleep(12)

# Connect premium proxy
print("[*] Deploying zero-drop network proxy layer...")
try:
    from pyngrok import ngrok
    public_url = ngrok.connect(8507, proto="http")
except Exception:
    # !pip install -q pyngrok
    from pyngrok import ngrok
    public_url = ngrok.connect(8507, proto="http")

print("\n" + "="*60)
print(f"🚀 FINAL FULLY OPERATIONAL RAG LINK: {public_url.public_url}")
print("="*60)
# Out:
# [*] Flushing background ports and system threads...
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:32:35+0000 lvl=warn msg="failed to open private leg" id=ecd1a5661197 privaddr=localhost:8507 err="dial tcp [::1]:8507: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:32:35+0000 lvl=warn msg="failed to open private leg" id=b8da2df3927f privaddr=localhost:8507 err="dial tcp [::1]:8507: connect: connection refused"
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ✅ Ngrok Authtoken successfully verified.
# [*] Spinning up the local reasoning server...
# [*] Loading local LLM weights into notebook memory (this takes ~10 seconds)...
# [*] Deploying zero-drop network proxy layer...
#
# ...
# 🚀 FINAL FULLY OPERATIONAL RAG LINK: https://phoniness-gigahertz-reawake.ngrok-free.dev
# ...

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
import torch
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFacePipeline
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# =====================================================================
# RESILIENT HUGGING FACE EMBEDDING IMPORTS
# =====================================================================
try:
    from langchain_huggingface import HuggingFaceEmbeddings
except ImportError:
    from langchain_community.embeddings import HuggingFaceEmbeddings

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Autonomous RAG Engine — Production Polish")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# CACHED BACKEND REASONING ENGINE (LIVE 100% FREE LOCAL LLM)
# =====================================================================
@st.cache_resource
def initialize_local_llm():
    model_id = "Qwen/Qwen2.5-0.5B-Instruct"

    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float32,
        device_map="auto"
    )

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=150,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )
    return HuggingFacePipeline(pipeline=pipe)

@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_local"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

# Instantiate live backends
system_retriever = initialize_persistent_backend()
live_llm = initialize_local_llm()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Evaluating the fully upgraded runtime engine."),
        AIMessage(content="Local reasoning model and Hugging Face neural pipeline are fully online. Drop a query to begin.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any specific question about your documentation...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # ChatML block generation for Qwen structural execution
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are a precise technical assistant. Answer the user's question clearly and concisely using ONLY the facts provided in the Verified Context records. If the answer cannot be found in the context, say 'Information not present in current documentation.'\n\nVerified Context:\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | live_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        retrieved_docs = system_retriever.invoke(user_input)

        with st.spinner("Local LLM processing logic..."):
            raw_response = lcel_rag_chain.invoke(runtime_payload)

            # PROMPT STRIPPING MATRIX: Splits away the generated context wrapper
            clean_response = raw_response
            if "assistant\n" in raw_response:
                clean_response = raw_response.split("assistant\n")[-1].strip()
            elif "<|im_start|>assistant" in raw_response:
                clean_response = raw_response.split("<|im_start|>assistant")[-1].strip()

            # Fallback check to avoid empty text rendering
            if not clean_response:
                clean_response = raw_response.strip()

        st.session_state.chat_history.append(AIMessage(content=clean_response))
        with st.chat_message("assistant"):
            st.write(clean_response)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
from google.colab import userdata

print("[*] Flushing background ports and system threads...")
# !pkill -f streamlit
# !pkill -f lt
# !pkill -f ngrok
time.sleep(2)

# Retrieve token safely from Secrets
try:
    NGROK_TOKEN = userdata.get('NGROK_AUTHTOKEN')
    if not NGROK_TOKEN:
        raise ValueError
    # !ngrok config add-authtoken {NGROK_TOKEN}
    print("✅ Ngrok Authtoken successfully verified.")
except Exception:
    print("❌ Error: 'NGROK_AUTHTOKEN' not found in Colab Secrets!")
    import sys
    sys.exit()

# Re-launch Streamlit server
print("[*] Re-initializing server backend...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8507",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
print("[*] Refreshing local model cache mapping...")
time.sleep(5)

# Connect proxy
print("[*] Deploying zero-drop network proxy layer...")
from pyngrok import ngrok
try:
    public_url = ngrok.connect(8507, proto="http")
except Exception:
    # !pip install -q pyngrok
    from pyngrok import ngrok
    public_url = ngrok.connect(8507, proto="http")

print("\n" + "="*60)
print(f"🚀 POLISHED LIVE RAG LINK: {public_url.public_url}")
print("="*60)
# Out:
# [*] Flushing background ports and system threads...
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:36:10+0000 lvl=warn msg="failed to open private leg" id=f6f8f624c3e8 privaddr=localhost:8507 err="dial tcp [::1]:8507: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:36:10+0000 lvl=warn msg="failed to open private leg" id=90a9d5b341ae privaddr=localhost:8507 err="dial tcp [::1]:8507: connect: connection refused"
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ✅ Ngrok Authtoken successfully verified.
# [*] Re-initializing server backend...
# [*] Refreshing local model cache mapping...
# [*] Deploying zero-drop network proxy layer...
#
# ...
# 🚀 POLISHED LIVE RAG LINK: https://phoniness-gigahertz-reawake.ngrok-free.dev
# ...

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
import torch
import re
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFacePipeline
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# =====================================================================
# RESILIENT HUGGING FACE EMBEDDING IMPORTS
# =====================================================================
try:
    from langchain_huggingface import HuggingFaceEmbeddings
except ImportError:
    from langchain_community.embeddings import HuggingFaceEmbeddings

# =====================================================================
# SYSTEM CONFIGURATION & PAGE LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Autonomous RAG Engine — Production Polish")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# CACHED BACKEND REASONING ENGINE (LIVE 100% FREE LOCAL LLM)
# =====================================================================
@st.cache_resource
def initialize_local_llm():
    model_id = "Qwen/Qwen2.5-0.5B-Instruct"

    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float32,
        device_map="auto"
    )

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=150,
        temperature=0.1,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id
    )
    return HuggingFacePipeline(pipeline=pipe)

@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_local"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

    vector_store = Chroma(
        persist_directory=db_path,
        embedding_function=embeddings_model
    )

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

# Instantiate live backends
system_retriever = initialize_persistent_backend()
live_llm = initialize_local_llm()

# =====================================================================
# CONVERSATIONAL STATE HISTORY MANAGEMENT
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Evaluating the fully upgraded runtime engine."),
        AIMessage(content="Local reasoning model and Hugging Face neural pipeline are fully online. Drop a query to begin.")
    ]

# =====================================================================
# INTERFACE PRESENTATION ENGINE
# =====================================================================
with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask any specific question about your documentation...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # Clear ChatML instruction mapping
        rag_prompt = ChatPromptTemplate.from_messages([
            ("system", "You are a precise technical assistant. Answer the user's question clearly and concisely using ONLY the facts provided in the Verified Context records. If the answer cannot be found in the context, say 'Information not present in current documentation.'\n\nVerified Context:\n{context}"),
            MessagesPlaceholder(variable_name="chat_history"),
            ("human", "{question}")
        ])

        lcel_rag_chain = (
            RunnableParallel({
                "context": lambda x: system_retriever.invoke(x["question"]),
                "chat_history": lambda x: x["chat_history"],
                "question": lambda x: x["question"]
            })
            | rag_prompt
            | live_llm
            | StrOutputParser()
        )

        runtime_payload = {
            "question": user_input,
            "chat_history": st.session_state.chat_history[:-1]
        }

        retrieved_docs = system_retriever.invoke(user_input)

        with st.spinner("Local LLM processing logic..."):
            raw_response = lcel_rag_chain.invoke(runtime_payload)

            # =====================================================================
            # FIXED: MULTI-STAGE PROMPT STRIPPING LAYER
            # =====================================================================
            clean_response = raw_response

            # 1. Break off everything before standard chat markers if present
            if "assistant\n" in clean_response:
                clean_response = clean_response.split("assistant\n")[-1]
            elif "<|im_start|>assistant" in clean_response:
                clean_response = clean_response.split("<|im_start|>assistant")[-1]

            # 2. Aggressive regex fallback: find the user query text or context blocks and slice them out
            # This handles instances where the model echoes the prompt format explicitly.
            if "Verified Context:" in clean_response:
                clean_response = clean_response.split("Verified Context:")[-1]

            # If the human prompt structure leaks, chop off everything until the last prompt block ends
            escaped_input = re.escape(user_input)
            matching_segments = list(re.finditer(escaped_input, clean_response))
            if matching_segments:
                last_match_idx = matching_segments[-1].end()
                clean_response = clean_response[last_match_idx:]

            # Final text cleanup pass to strip leftover bracket closures or spacing artifacts
            clean_response = re.sub(r'^[^a-zA-Z0-9]+', '', clean_response).strip()

            # Safety check: If post-processing leaves us with blank data, fall back to raw
            if not clean_response:
                clean_response = raw_response.strip()

        st.session_state.chat_history.append(AIMessage(content=clean_response))
        with st.chat_message("assistant"):
            st.write(clean_response)

with col_inspect:
    st.subheader("Vector Store Inspector")
    st.info("This telemetry sidebar displays what the database retrieved in real-time before sending data to the LLM model layer.")

    if user_input and 'retrieved_docs' in locals() and retrieved_docs:
        st.success(f"🎯 Document Match Found for: '{user_input}'")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
            st.caption(f"Source Metadata: {doc.metadata}")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
from google.colab import userdata

print("[*] Flushing background ports and system threads...")
# !pkill -f streamlit
# !pkill -f lt
# !pkill -f ngrok
time.sleep(2)

# Retrieve token safely from Secrets
try:
    NGROK_TOKEN = userdata.get('NGROK_AUTHTOKEN')
    if not NGROK_TOKEN:
        raise ValueError
    # !ngrok config add-authtoken {NGROK_TOKEN}
    print("✅ Ngrok Authtoken successfully verified.")
except Exception:
    print("❌ Error: 'NGROK_AUTHTOKEN' not found in Colab Secrets!")
    import sys
    sys.exit()

# Re-launch Streamlit server
print("[*] Re-initializing server backend...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8507",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
print("[*] Refreshing local model cache mapping...")
time.sleep(5)

# Connect proxy
print("[*] Deploying zero-drop network proxy layer...")
from pyngrok import ngrok
try:
    public_url = ngrok.connect(8507, proto="http")
except Exception:
    # !pip install -q pyngrok
    from pyngrok import ngrok
    public_url = ngrok.connect(8507, proto="http")

print("\n" + "="*60)
print(f"🚀 POLISHED LIVE RAG LINK: {public_url.public_url}")
print("="*60)
# Out:
# [*] Flushing background ports and system threads...
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:39:30+0000 lvl=warn msg="failed to open private leg" id=6f01e041de9a privaddr=localhost:8507 err="dial tcp [::1]:8507: connect: connection refused"
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:39:30+0000 lvl=warn msg="failed to open private leg" id=19e58e40bfd5 privaddr=localhost:8507 err="dial tcp [::1]:8507: connect: connection refused"
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ✅ Ngrok Authtoken successfully verified.
# [*] Re-initializing server backend...
# [*] Refreshing local model cache mapping...
# [*] Deploying zero-drop network proxy layer...
#
# ...
# 🚀 POLISHED LIVE RAG LINK: https://phoniness-gigahertz-reawake.ngrok-free.dev
# ...

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
import torch
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFacePipeline
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# =====================================================================
# CORE CONFIGURATION & LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Autonomous RAG Engine — ChatML Enforced")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# BACKEND INITIALIZATION (CACHED)
# =====================================================================
@st.cache_resource
def initialize_local_llm():
    model_id = "Qwen/Qwen2.5-0.5B-Instruct"
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float32,
        device_map="auto"
    )

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=100,
        temperature=0.1,  # Keep it highly deterministic
        do_sample=False,
        repetition_penalty=1.2, # Penalize repetitive looping behavior
        pad_token_id=tokenizer.eos_token_id
    )
    return HuggingFacePipeline(pipeline=pipe)

@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_local"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vector_store = Chroma(persist_directory=db_path, embedding_function=embeddings_model)

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

system_retriever = initialize_persistent_backend()
live_llm = initialize_local_llm()

# =====================================================================
# CONVERSATIONAL RECOVERY & UI
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Checking system status."),
        AIMessage(content="Local ChatML pipeline initialized. Send a blueprint query.")
    ]

with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask a question about your architecture files...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        # ChatML structural mapping specifically engineered for Qwen model types
        chatml_template = (
            "<|im_start|>system\n"
            "You are a helpful assistant. Use the following pieces of context to answer the question at the end. "
            "If you do not know the answer, say 'Information not present in current documentation.' Do not make up information.\n\n"
            "Context:\n{context}<|im_end|>\n"
            "<|im_start|>user\n"
            "{question}<|im_end|>\n"
            "<|im_start|>assistant\n"
        )

        prompt = PromptTemplate(
            template=chatml_template,
            input_variables=["context", "question"]
        )

        lcel_chain = (
            RunnableParallel({
                "context": lambda x: "\n".join([d.page_content for d in system_retriever.invoke(x["question"])]),
                "question": lambda x: x["question"]
            })
            | prompt
            | live_llm
            | StrOutputParser()
        )

        with st.spinner("Processing local inference..."):
            raw_response = lcel_chain.invoke({"question": user_input})

            # Extract just the newly generated assistant tokens
            if "assistant\n" in raw_response:
                clean_response = raw_response.split("assistant\n")[-1].replace("<|im_end|>", "").strip()
            else:
                clean_response = raw_response.strip()

        st.session_state.chat_history.append(AIMessage(content=clean_response))
        with st.chat_message("assistant"):
            st.write(clean_response)

with col_inspect:
    st.subheader("Vector Store Inspector")
    retrieved_docs = system_retriever.invoke(user_input) if user_input else []
    if user_input and retrieved_docs:
        st.success(f"🎯 Document Match Found!")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
from google.colab import userdata

print("[*] Recycling stuck memory execution states...")
# !pkill -f streamlit
# !pkill -f lt
# !pkill -f ngrok
time.sleep(2)

# Verify security tokens
try:
    NGROK_TOKEN = userdata.get('NGROK_AUTHTOKEN')
    # !ngrok config add-authtoken {NGROK_TOKEN}
    print("✅ Secrets token successfully verified.")
except Exception:
    print("❌ Error: 'NGROK_AUTHTOKEN' missing in Secrets panel.")
    import sys
    sys.exit()

# Start application server
print("[*] Launching system backend...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8507",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(5)

# Deploy proxy tunnel
print("[*] Starting secure production proxy tunnel...")
from pyngrok import ngrok
public_url = ngrok.connect(8507, proto="http")

print("\n" + "="*60)
print(f"🚀 PRODUCTION READY RAG LINK: {public_url.public_url}")
print("="*60)
# Out:
# [*] Recycling stuck memory execution states...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ✅ Secrets token successfully verified.
# [*] Launching system backend...
# [*] Starting secure production proxy tunnel...
#
# ...
# 🚀 PRODUCTION READY RAG LINK: https://phoniness-gigahertz-reawake.ngrok-free.dev
# ...

# %%
# %%writefile app.py
import streamlit as st
import os
import gc
import torch
import re
from langchain_core.runnables import RunnableParallel
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import AIMessage, HumanMessage
from langchain_chroma import Chroma
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import pipeline, AutoModelForCausalLM, AutoTokenizer

# =====================================================================
# FIXED: SECURE UNIFIED EMBEDDING RESOLUTION MATRIX
# =====================================================================
try:
    from langchain_huggingface import HuggingFaceEmbeddings
except ImportError:
    from langchain_community.embeddings import HuggingFaceEmbeddings

# =====================================================================
# CORE CONFIGURATION & LAYOUT
# =====================================================================
st.set_page_config(page_title="RAG Systems Core Prototype", layout="wide")
st.title("🤖 Systems Architecture Prototype Panel")
st.caption("100% Free Local Autonomous RAG Engine — Production Version")

col_chat, col_inspect = st.columns([2, 1])

# =====================================================================
# BACKEND INITIALIZATION (CACHED)
# =====================================================================
@st.cache_resource
def initialize_local_llm():
    model_id = "Qwen/Qwen2.5-0.5B-Instruct"
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float32,
        device_map="auto"
    )

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=100,
        temperature=0.1,
        do_sample=False,
        repetition_penalty=1.2,
        pad_token_id=tokenizer.eos_token_id
    )
    return HuggingFacePipeline(pipeline=pipe)

@st.cache_resource
def initialize_persistent_backend():
    gc.collect()
    db_path = "./chroma_db_local"
    knowledge_folder = "./knowledge_base"

    if not os.path.exists(knowledge_folder):
        os.makedirs(knowledge_folder)
        default_file = os.path.join(knowledge_folder, "architecture_blueprint.txt")
        with open(default_file, "w") as f:
            f.write("LangChain is an enterprise framework designed to simplify LLM development via declarative orchestration graph layers.\n"
                    "RAG optimizes LLM generations by dynamically intercepting user payloads and injecting verified external knowledge store contexts before execution.\n"
                    "Sprints organize engineering workflows into tight, measurable iterations to maintain a steady project velocity.")

    loader = DirectoryLoader(knowledge_folder, glob="**/*.txt", loader_cls=TextLoader)
    raw_documents = loader.load()

    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_docs = text_splitter.split_documents(raw_documents)

    # Resolves directly to whichever wrapper is mounted in the Python environment
    embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vector_store = Chroma(persist_directory=db_path, embedding_function=embeddings_model)

    if split_docs:
        vector_store.add_documents(split_docs)

    return vector_store.as_retriever(search_kwargs={"k": 2})

# Safe dynamic wrapper mapping for runtime pipeline validation
try:
    from langchain_huggingface import HuggingFacePipeline
except ImportError:
    from langchain_community.llms import HuggingFacePipeline

system_retriever = initialize_persistent_backend()
live_llm = initialize_local_llm()

# =====================================================================
# CONVERSATIONAL RECOVERY & UI
# =====================================================================
if "chat_history" not in st.session_state:
    st.session_state.chat_history = [
        HumanMessage(content="Hello! Checking system status."),
        AIMessage(content="Local ChatML pipeline initialized. Send a blueprint query.")
    ]

with col_chat:
    st.subheader("Live Multi-Turn Chat Layer")

    for msg in st.session_state.chat_history:
        if isinstance(msg, HumanMessage):
            with st.chat_message("user"):
                st.write(msg.content)
        elif isinstance(msg, AIMessage):
            with st.chat_message("assistant"):
                st.write(msg.content)

    user_input = st.chat_input("Ask a question about your architecture files...")

    if user_input:
        st.session_state.chat_history.append(HumanMessage(content=user_input))
        with st.chat_message("user"):
            st.write(user_input)

        chatml_template = (
            "<|im_start|>system\n"
            "You are a helpful assistant. Use the following pieces of context to answer the question at the end. "
            "If you do not know the answer, say 'Information not present in current documentation.' Do not make up information.\n\n"
            "Context:\n{context}<|im_end|>\n"
            "<|im_start|>user\n"
            "{question}<|im_end|>\n"
            "<|im_start|>assistant\n"
        )

        prompt = PromptTemplate(
            template=chatml_template,
            input_variables=["context", "question"]
        )

        lcel_chain = (
            RunnableParallel({
                "context": lambda x: "\n".join([d.page_content for d in system_retriever.invoke(x["question"])]),
                "question": lambda x: x["question"]
            })
            | prompt
            | live_llm
            | StrOutputParser()
        )

        with st.spinner("Processing local inference..."):
            raw_response = lcel_chain.invoke({"question": user_input})

            clean_response = raw_response
            if "assistant\n" in raw_response:
                clean_response = raw_response.split("assistant\n")[-1].replace("<|im_end|>", "").strip()
            else:
                clean_response = raw_response.strip()

        st.session_state.chat_history.append(AIMessage(content=clean_response))
        with st.chat_message("assistant"):
            st.write(clean_response)

with col_inspect:
    st.subheader("Vector Store Inspector")
    retrieved_docs = system_retriever.invoke(user_input) if user_input else []
    if user_input and retrieved_docs:
        st.success(f"🎯 Document Match Found!")
        for i, doc in enumerate(retrieved_docs):
            st.markdown(f"**Chunk ID {i+1}**")
            st.code(doc.page_content, language="text")
    else:
        st.write("Waiting for system query generation...")
# Out:
# Overwriting app.py

# %%
import subprocess
import time
from google.colab import userdata

print("[*] Flushing background ports and memory states...")
# !pkill -f streamlit
# !pkill -f lt
# !pkill -f ngrok
time.sleep(2)

try:
    NGROK_TOKEN = userdata.get('NGROK_AUTHTOKEN')
    # !ngrok config add-authtoken {NGROK_TOKEN}
    print("✅ Ngrok Authtoken successfully verified.")
except Exception:
    print("❌ Error: 'NGROK_AUTHTOKEN' missing in Secrets panel.")
    import sys
    sys.exit()

print("[*] Launching system backend...")
subprocess.Popen([
    "streamlit", "run", "app.py",
    "--server.port", "8507",
    "--server.headless", "true",
    "--browser.gatherUsageStats", "false"
])
time.sleep(5)

print("[*] Starting secure production proxy tunnel...")
from pyngrok import ngrok
public_url = ngrok.connect(8507, proto="http")

print("\n" + "="*60)
print(f"🚀 VERIFIED LIVE RAG LINK: {public_url.public_url}")
print("="*60)
# Out:
# [*] Flushing background ports and memory states...
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:48:30+0000 lvl=warn msg="Stopping forwarder" name=http-8507-dc5e023d-1fb8-4bb3-8887-4d12eea660ae acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2026-05-17T09:48:30+0000 lvl=warn msg="Error restarting forwarder" name=http-8507-dc5e023d-1fb8-4bb3-8887-4d12eea660ae err="failed to start tunnel: remote gone away"
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ✅ Ngrok Authtoken successfully verified.
# [*] Launching system backend...
# [*] Starting secure production proxy tunnel...
#
# ...
# 🚀 VERIFIED LIVE RAG LINK: https://phoniness-gigahertz-reawake.ngrok-free.dev
# ...
